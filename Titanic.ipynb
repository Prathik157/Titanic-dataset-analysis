# %% [markdown]
# # Data analysis on Titanic dataset

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aprat\\OneDrive\\Desktop\\EDA'

# %%
os.chdir(r'C:\Users\aprat\OneDrive\Desktop\EDA')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('tested.csv')

# %%
df.head(40)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Sex']=df['Sex'].map({'male':0,'female':1})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
sns.countplot(x=df['Embarked'],hue=df['Survived'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# # Observation:
#     * Upon observing the above visuals, we can infer that as per the percentage of survived people among different          embarkments , people boarded from cherborg have survived in more numbers when compared to percentage of survival of         other embakments.

# %%
sns.countplot(x=df['Embarked'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# # Observation:
#     *We can see that most of the passengers have boarded from southampton

# %%
sns.barplot(x='Sex',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# # Observation:
#     * No men were survived

# %%
sns.countplot(x=df['Sex'],hue=df['Pclass'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# # Observation :
#     * Both men and women have chosen passenger class - 3 for travel

# %%
sns.relplot(x='Pclass',y='Survived',hue='Embarked',data=df,kind='line')

# %% [markdown]
# # Observation:
#
#     * Most of the people survived in the sink was people from passenger class - 1  and  people of embarkment Queenstown.
#     * Pclass-1 contains more people who have boarded from Queenstown.
#     * Pclass-2 contains more people who have boarded from cherborg.
#     * Pclass-3 contains more people who have boarded from southampton.

# %%
sns.countplot(x=df['Pclass'],hue=df['Survived'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# # Observation:
#     * Most people from Passenger class 3 have died and the safest passenger class was Pclass 1 where the fare of ticket is   high.

# %%
sns.countplot(x=df['Pclass'],hue=df['Embarked'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# # Observation :
#     * Passenger class 1 was booked by most of the people from cherborg.
#     * Passenger class 2 and 3 were booked by people from southampton.

# %%
sns.distplot(a=df['Age'],kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Observation :
#     * Most of the people travelling are of the age between 20 - 30 years.

# %%
df['Embarked']=df['Embarked'].map({'S':1,'C':2,'Q':3})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare Cabin  Embarked
# 0   330911   7.8292   NaN         3
# 1   363272   7.0000   NaN         1
# 2   240276   9.6875   NaN         3
# 3   315154   8.6625   NaN         1
# 4  3101298  12.2875   NaN         1

# %%
df['Cabin'].value_counts()
# Out:
# B57 B59 B63 B66    3
# B45                2
# C89                2
# C55 C57            2
# A34                2
#                   ..
# E52                1
# D30                1
# E31                1
# C62 C64            1
# C105               1
# Name: Cabin, Length: 76, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: Age, Length: 79, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['Age'].mode()[0]
# Out:
# 21.0

# %%
df['Age']=df['Age'].fillna(df['Age'].mode()[0])

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Fare']=df['Fare'].fillna(df['Fare'].mode()[0])

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
df['Cabin']=df['Cabin'].fillna(df['Cabin'].mode()[0])

# %%
df['Cabin'].isnull().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare            Cabin  Embarked
# 0   330911   7.8292  B57 B59 B63 B66         3
# 1   363272   7.0000  B57 B59 B63 B66         1
# 2   240276   9.6875  B57 B59 B63 B66         3
# 3   315154   8.6625  B57 B59 B63 B66         1
# 4  3101298  12.2875  B57 B59 B63 B66         1

# %%
sns.pairplot(df)

# %%
sns.barplot(x='Pclass',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # Observation:
#     * Most of the elder people were present in passenger class - 1

# %%
from sklearn.linear_model import LinearRegression

# %%
out=df['Survived']

# %%
df=df.drop('Survived',axis=1)

# %%
out.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Survived, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#     Age  SibSp  Parch   Ticket     Fare            Cabin  Embarked
# 0  34.5      0      0   330911   7.8292  B57 B59 B63 B66         3
# 1  47.0      1      0   363272   7.0000  B57 B59 B63 B66         1
# 2  62.0      0      0   240276   9.6875  B57 B59 B63 B66         3
# 3  27.0      0      0   315154   8.6625  B57 B59 B63 B66         1
# 4  22.0      1      1  3101298  12.2875  B57 B59 B63 B66         1

# %%
df.drop(['Name','PassengerId','Fare','Ticket','Cabin'],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,out,test_size=0.30,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
# Out:
# array([[-1.47596812, -0.78310898,  0.51324935, -0.50269793, -0.43509701,
#          0.76543068],
#        [ 0.8727114 , -0.78310898, -0.57692234, -0.50269793, -0.43509701,
#          2.22625262],
#        [-1.47596812,  1.27696148,  2.47555838,  0.5766241 , -0.43509701,
#         -0.69539127],
#        ...,
#        [-1.47596812, -0.78310898,  1.24003047, -0.50269793, -0.43509701,
#          0.76543068],
#        [-0.30162836, -0.78310898, -0.358888  , -0.50269793, -0.43509701,
#         -0.69539127],
#        [ 0.8727114 , -0.78310898, -0.57692234, -0.50269793, -0.43509701,
#          2.22625262]])

# %%
x_test=scaler.transform(x_test)

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg_pred=regression.predict(x_test)
# Out:
# C:\Users\aprat\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg_pred
# Out:
# array([-0.78310898,  1.27696148, -0.78310898, -0.78310898,  1.27696148,
#        -0.78310898,  1.27696148, -0.78310898,  1.27696148, -0.78310898,
#        -0.78310898,  1.27696148,  1.27696148,  1.27696148, -0.78310898,
#        -0.78310898,  1.27696148, -0.78310898, -0.78310898, -0.78310898,
#        -0.78310898, -0.78310898,  1.27696148, -0.78310898,  1.27696148,
#         1.27696148,  1.27696148, -0.78310898, -0.78310898, -0.78310898,
#        -0.78310898,  1.27696148,  1.27696148, -0.78310898,  1.27696148,
#        -0.78310898,  1.27696148, -0.78310898,  1.27696148, -0.78310898,
#         1.27696148,  1.27696148, -0.78310898, -0.78310898, -0.78310898,
#        -0.78310898,  1.27696148,  1.27696148,  1.27696148, -0.78310898,
#        -0.78310898,  1.27696148,  1.27696148, -0.78310898, -0.78310898,
#         1.27696148, -0.78310898, -0.78310898,  1.27696148, -0.78310898,
#        -0.78310898, -0.78310898,  1.27696148, -0.78310898,  1.27696148,
# ...

# %%
from sklearn.metrics import r2_score
score=r2_score(reg_pred,y_test)

# %%
score
# Out:
# 0.5291208410686679
